# %%
# !ls data
# Out:
# gapminder_all.csv	  gapminder_gdp_americas.csv  gapminder_gdp_europe.csv
# gapminder_gdp_africa.csv  gapminder_gdp_asia.csv      gapminder_gdp_oceania.csv

# %%
# !cat data/gapminder_gdp_europe.csv | head -n 5
# Out:
# country,gdpPercap_1952,gdpPercap_1957,gdpPercap_1962,gdpPercap_1967,gdpPercap_1972,gdpPercap_1977,gdpPercap_1982,gdpPercap_1987,gdpPercap_1992,gdpPercap_1997,gdpPercap_2002,gdpPercap_2007
# Albania,1601.056136,1942.284244,2312.888958,2760.196931,3313.422188,3533.00391,3630.880722,3738.932735,2497.437901,3193.054604,4604.211737,5937.029526
# Austria,6137.076492,8842.59803,10750.72111,12834.6024,16661.6256,19749.4223,21597.08362,23687.82607,27042.01868,29095.92066,32417.60769,36126.4927
# Belgium,8343.105127,9714.960623,10991.20676,13149.04119,16672.14356,19117.97448,20979.84589,22525.56308,25575.57069,27561.19663,30485.88375,33692.60508
# Bosnia and Herzegovina,973.5331948,1353.989176,1709.683679,2172.352423,2860.16975,3528.481305,4126.613157,4314.114757,2546.781445,4766.355904,6018.975239,7446.298803

# %%
import numpy

# %%
data = numpy.loadtxt('data/gapminder_gdp_europe.csv',
                     usecols=range(1, 13),
                     skiprows=1,
                     delimiter=',')

# %%
print(data)
# Out:
# [[ 1601.056136   1942.284244   2312.888958   2760.196931   3313.422188
#    3533.00391    3630.880722   3738.932735   2497.437901   3193.054604
#    4604.211737   5937.029526 ]
#  [ 6137.076492   8842.59803   10750.72111   12834.6024    16661.6256
#   19749.4223    21597.08362   23687.82607   27042.01868   29095.92066
#   32417.60769   36126.4927   ]
#  [ 8343.105127   9714.960623  10991.20676   13149.04119   16672.14356
#   19117.97448   20979.84589   22525.56308   25575.57069   27561.19663
#   30485.88375   33692.60508  ]
#  [  973.5331948  1353.989176   1709.683679   2172.352423   2860.16975
#    3528.481305   4126.613157   4314.114757   2546.781445   4766.355904
#    6018.975239   7446.298803 ]
#  [ 2444.286648   3008.670727   4254.337839   5577.0028     6597.494398
#    7612.240438   8224.191647   8239.854824   6302.623438   5970.38876
#    7696.777725  10680.79282  ]
#  [ 3119.23652    4338.231617   5477.890018   6960.297861   9164.090127
#   11305.38517   13221.82184   13822.58394    8447.794873   9875.604515
#   11628.38895   14619.22272  ]
#  [ 6876.14025    8256.343918  10136.86713   11399.44489   13108.4536
#   14800.16062   15377.22855   16310.4434    14297.02122   16048.51424
#   17596.21022   22833.30851  ]
#  [ 9692.385245  11099.65935   13583.31351   15937.21123   18866.20721
#   20422.9015    21688.04048   25116.17581   26406.73985   29804.34567
#   32166.50006   35278.41874  ]
#  [ 6424.519071   7545.415386   9371.842561  10921.63626   14358.8759
#   15605.42283   18533.15761   21141.01223   20647.16499   23723.9502
#   28204.59057   33207.0844   ]
#  [ 7029.809327   8662.834898  10560.48553   12999.91766   16107.19171
#   18292.63514   20293.89746   22066.44214   24703.79615   25889.78487
#   28926.03234   30470.0167   ]
#  [ 7144.114393  10187.82665   12902.46291   14745.62561   18016.18027
#   20512.92123   22031.53274   24639.18566   26505.30317   27788.88416
#   30035.80198   32170.37442  ]
#  [ 3530.690067   4916.299889   6017.190733   8513.097016  12724.82957
#   14195.52428   15268.42089   16120.52839   17541.49634   18747.69814
#   22514.2548    27538.41188  ]
#  [ 5263.673816   6040.180011   7550.359877   9326.64467   10168.65611
#   11674.83737   12545.99066   12986.47998   10535.62855   11712.7768
#   14843.93556   18008.94444  ]
#  [ 7267.688428   9244.001412  10350.15906   13319.89568   15798.06362
#   19654.96247   23269.6075    26923.20628   25144.39201   28061.09966
#   31163.20196   36180.78919  ]
#  [ 5210.280328   5599.077872   6631.597314   7655.568963   9530.772896
#   11150.98113   12618.32141   13872.86652   17558.81555   24521.94713
#   34077.04939   40675.99635  ]
#  [ 4931.404155   6248.656232   8243.58234   10022.40131   12269.27378
#   14255.98475   16537.4835    19207.23482   22013.64486   24675.02446
#   27968.09817   28569.7197   ]
#  [ 2647.585601   3682.259903   4649.593785   5907.850937   7778.414017
#    9595.929905  11222.58762   11732.51017    7003.339037   6465.613349
#    6557.194282   9253.896111 ]
#  [ 8941.571858  11276.19344   12790.84956   15363.25136   18794.74567
#   21209.0592    21399.46046   23651.32361   26790.94961   30246.13063
#   33724.75778   36797.93332  ]
#  [10095.42172   11653.97304   13450.40151   16361.87647   18965.05551
#   23311.34939   26298.63531   31540.9748    33965.66115   41283.16433
#   44683.97525   49357.19017  ]
#  [ 4029.329699   4734.253019   5338.752143   6557.152776   8006.506993
#    9508.141454   8451.531004   9082.351172   7738.881247  10159.58368
#   12002.23908   15389.92468  ]
#  [ 3068.319867   3774.571743   4727.954889   6361.517993   9022.247417
#   10172.48572   11753.84291   13039.30876   16207.26663   17641.03156
#   19970.90787   20509.64777  ]
#  [ 3144.613186   3943.370225   4734.997586   6470.866545   8011.414402
#    9356.39724    9605.314053   9696.273295   6598.409903   7346.547557
#    7885.360081  10808.47561  ]
#  [ 3581.459448   4981.090891   6289.629157   7991.707066  10522.06749
#   12980.66956   15181.0927    15870.87851    9325.068238   7914.320304
#    7236.075251   9786.534714 ]
#  [ 5074.659104   6093.26298    7481.107598   8412.902397   9674.167626
#   10922.66404   11348.54585   12037.26758    9498.467723  12126.23065
#   13638.77837   18678.31435  ]
#  [ 4215.041741   5862.276629   7402.303395   9405.489397  12383.4862
#   15277.03017   17866.72175   18678.53492   14214.71681   17161.10735
#   20660.01936   25768.25759  ]
#  [ 3834.034742   4564.80241    5693.843879   7993.512294  10638.75131
#   13236.92117   13926.16997   15764.98313   18603.06452   20445.29896
#   24835.47166   28821.0637   ]
#  [ 8527.844662   9911.878226  12329.44192   15258.29697   17832.02464
#   18855.72521   20667.38125   23586.92927   23880.01683   25266.59499
#   29341.63093   33859.74835  ]
#  [14734.23275   17909.48973   20431.0927    22966.14432   27195.11304
#   26982.29052   28397.71512   30281.70459   31871.5303    32135.32301
#   34480.95771   37506.41907  ]
#  [ 1969.10098    2218.754257   2322.869908   2826.356387   3450.69638
#    4269.122326   4241.356344   5089.043686   5678.348271   6601.429915
#    6508.085718   8458.276384 ]
#  [ 9979.508487  11283.17795   12477.17707   14142.85089   15895.11641
#   17428.74846   18232.42452   21664.78767   22705.09254   26074.53136
#   29478.99919   33203.26128  ]]

# %%
print(data.shape)
# Out:
# (30, 12)

# %%
print(data[0, 1])
# Out:
# 1942.284244

# %%
print(data[34])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(data[34])
#
# IndexError: index 34 is out of bounds for axis 0 with size 30

# %%
print(data[2])
# Out:
# [ 8343.105127  9714.960623 10991.20676  13149.04119  16672.14356
#  19117.97448  20979.84589  22525.56308  22525.56308  27561.19663
#  30485.88375  33692.60508 ]

# %%
print(arr.dtype)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(arr.dtype)
#
# NameError: name 'arr' is not defined

# %%
print(data[3:7, 2:7])
# Out:
# [[ 1709.683679  2172.352423  2860.16975   3528.481305  4126.613157]
#  [ 4254.337839  5577.0028    6597.494398  7612.240438  8224.191647]
#  [ 5477.890018  6960.297861  9164.090127 11305.38517  13221.82184 ]
#  [10136.86713  11399.44489  13108.4536   14800.16062  15377.22855 ]]

# %%
import matplotlib.pyplot as plt

# %%
years = np.arange(1952, 2008, 5)

# %%
print(years)
# Out:
# [1952 1957 1962 1967 1972 1977 1982 1987 1992 1997 2002 2007]

# %%
plt.plot(years, data[0], label="Albania")
plt.plot(years, data[1], label="Austria")
plt.plot(years, data[2], label='Belgium')
plt.plot(years, data[3], label='B&H')
plt.legend()

# %% [markdown]
# # Pandas

# %%
import pandas as pd
data = pd.read_csv('data/gapminder_gdp_europe.csv', index_col='country')
print(data.iloc[0, 0])
# Out:
# 1601.056136

# %%
# !ls
# Out:
# data  python-novice-gapminder-data.zip	Untitled.ipynb

# %%
# !ls data
# Out:
# gapminder_all.csv	  gapminder_gdp_americas.csv  gapminder_gdp_europe.csv
# gapminder_gdp_africa.csv  gapminder_gdp_asia.csv      gapminder_gdp_oceania.csv

# %%
# !cat data/gapminder_gdp_europe.csv | head -n 2
# Out:
# country,gdpPercap_1952,gdpPercap_1957,gdpPercap_1962,gdpPercap_1967,gdpPercap_1972,gdpPercap_1977,gdpPercap_1982,gdpPercap_1987,gdpPercap_1992,gdpPercap_1997,gdpPercap_2002,gdpPercap_2007
# Albania,1601.056136,1942.284244,2312.888958,2760.196931,3313.422188,3533.00391,3630.880722,3738.932735,2497.437901,3193.054604,4604.211737,5937.029526

# %%
print(data.loc["Albania", "gdpPercap_1952"])
# Out:
# 1601.056136

# %%
print(data.loc["Albania", :])
# Out:
# gdpPercap_1952    1601.056136
# gdpPercap_1957    1942.284244
# gdpPercap_1962    2312.888958
# gdpPercap_1967    2760.196931
# gdpPercap_1972    3313.422188
# gdpPercap_1977    3533.003910
# gdpPercap_1982    3630.880722
# gdpPercap_1987    3738.932735
# gdpPercap_1992    2497.437901
# gdpPercap_1997    3193.054604
# gdpPercap_2002    4604.211737
# gdpPercap_2007    5937.029526
# Name: Albania, dtype: float64

# %%
print(data.loc[:, "gdpPercap_1952"])
# Out:
# country
# Albania                    1601.056136
# Austria                    6137.076492
# Belgium                    8343.105127
# Bosnia and Herzegovina      973.533195
# Bulgaria                   2444.286648
# Croatia                    3119.236520
# Czech Republic             6876.140250
# Denmark                    9692.385245
# Finland                    6424.519071
# France                     7029.809327
# Germany                    7144.114393
# Greece                     3530.690067
# Hungary                    5263.673816
# Iceland                    7267.688428
# Ireland                    5210.280328
# Italy                      4931.404155
# Montenegro                 2647.585601
# Netherlands                8941.571858
# Norway                    10095.421720
# Poland                     4029.329699
# Portugal                   3068.319867
# Romania                    3144.613186
# Serbia                     3581.459448
# Slovak Republic            5074.659104
# Slovenia                   4215.041741
# Spain                      3834.034742
# Sweden                     8527.844662
# Switzerland               14734.232750
# Turkey                     1969.100980
# United Kingdom             9979.508487
# Name: gdpPercap_1952, dtype: float64

# %%
print(data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972'])
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %%
print(data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972'].max())
# Out:
# gdpPercap_1962    13450.40151
# gdpPercap_1967    16361.87647
# gdpPercap_1972    18965.05551
# dtype: float64

# %%
print(data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972'].min())
# Out:
# gdpPercap_1962    4649.593785
# gdpPercap_1967    5907.850937
# gdpPercap_1972    7778.414017
# dtype: float64

# %%
# !ls
# Out:
# data  python-novice-gapminder-data.zip	Untitled.ipynb

# %%
data_oceania_country = pd.read_csv('data/gapminder_gdp_oceania.csv', index_col='country')

# %%
print(data_oceania_country)
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data_oceania_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gdpPercap_1952  2 non-null      float64
#  1   gdpPercap_1957  2 non-null      float64
#  2   gdpPercap_1962  2 non-null      float64
#  3   gdpPercap_1967  2 non-null      float64
#  4   gdpPercap_1972  2 non-null      float64
#  5   gdpPercap_1977  2 non-null      float64
#  6   gdpPercap_1982  2 non-null      float64
#  7   gdpPercap_1987  2 non-null      float64
#  8   gdpPercap_1992  2 non-null      float64
#  9   gdpPercap_1997  2 non-null      float64
#  10  gdpPercap_2002  2 non-null      float64
#  11  gdpPercap_2007  2 non-null      float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
print(data_oceania_country.columns)
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
print(data_oceania_country.T)
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
print(data_oceania_country.describe())
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# min       16046.03728    16233.717700    17632.410400    19007.191290
# 25%       16231.68533    16758.837652    18093.560120    19727.615725
# 50%       16417.33338    17283.957605    18554.709840    20448.040160
# 75%       16602.98143    17809.077558    19015.859560    21168.464595
# max       16788.62948    18334.197510    19477.009280    21888.889030
#
#        gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# count        2.000000        2.000000        2.000000        2.000000
# mean     20894.045885    24024.175170    26938.778040    29810.188275
# std       3578.979883     4205.533703     5301.853680     6540.991104
# min      18363.324940    21050.413770    23189.801350    25185.009110
# 25%      19628.685412    22537.294470    25064.289695    27497.598692
# 50%      20894.045885    24024.175170    26938.778040    29810.188275
# 75%      22159.406358    25511.055870    28813.266385    32122.777858
# max      23424.766830    26997.936570    30687.754730    34435.367440

# %% [markdown]
# - wow
# - hello
# - blah

# %%
import pandas as pd
data = pd.read_csv('data/gapminder_gdp_europe.csv', index_col='country')
print(data.iloc[0, 0])
# Out:
# 1601.056136

# %%
import pandas as pd

data = pd.read_csv('data/gapminder_gdp_oceania.csv', index_col='country')

# Extract year from last 4 characters of each column name
# The current column names are structured as 'gdpPercap_(year)', 
# so we want to keep the (year) part only for clarity when plotting GDP vs. years
# To do this we use replace(), which removes from the string the characters stated in the argument
# This method works on strings, so we use replace() from Pandas Series.str vectorized string functions

years = data.columns.str.replace('gdpPercap_', '')

# Convert year values to integers, saving results back to dataframe

data.columns = years.astype(int)

data.loc['Australia'].plot()
# Out:
# <Axes: >

# %%
data.T.plot()
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
plt.style.use('ggplot')
data.T.plot(kind='bar')
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')
